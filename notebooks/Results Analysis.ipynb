# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from mpl_toolkits.axes_grid1 import ImageGrid

# %%
# %matplotlib inline

# %%
demo = mpimg.imread('../demo.png')
test_image = mpimg.imread('../DATA/lung_data/testing/lung_images/004-CT-7358-0010.png')

# %%
fig = plt.figure(1, (12., 12.))
grid = ImageGrid(fig, 111,  # similar to subplot(111)
                 nrows_ncols=(1, 2),  # creates 2x2 grid of axes
                 axes_pad=0.1,  # pad between axes in inch.
                 )

for i, im in zip(range(2), [demo, test_image]):
    grid[i].imshow(im)  # The AxesGrid object work as a list of axes.

# %%
demo.shape
# Out:
# (375, 1242, 3)

# %%
img_wo_alpha = test_image[:,:,:3]

# %%
rshp = mpimg.imread('../reshape_lung.png')

# %%
# Out:
# (512, 512, 4)

# %%
plt.imsave("rshp_lung.png", test_image[:,:,:3])

# %%
rshp = mpimg.imread('rshp_lung.png')
rshp.shape
# Out:
# (512, 512, 4)
